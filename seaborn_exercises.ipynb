# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pydataset

# %% [markdown]
# Use seaborn's load_dataset function to load the iris database to answer the following questions:

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# What does the distribution of petal lengths look like?

# %%
sns.histplot(df.petal_length)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# Is there a relationship between petal length and petal width?

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# Would it be reasonable to predict species based on sepal width and sepal length? For this, you'll visualize two numeric columns through the lense of a categorical column.

# %%
sns.scatterplot(data=df, x='sepal_width', y='sepal_length', hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# Which features would be best used to predict species?

# %%
sns.pairplot(df, hue='species', corner=True)

# %% [markdown]
# Load the anscombe dataset from seaborn. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?
#
#     Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
df = sns.load_dataset('anscombe')
df.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sns.relplot(data=df, x='x', y='y', col='dataset')

# %% [markdown]
# Load the InsectSprays dataset from pydataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
df = pydataset.data('InsectSprays')
sns.boxplot(data=df, x='count', y='spray')
# Out:
# <Axes: xlabel='count', ylabel='spray'>

# %% [markdown]
# Load the swiss dataset from pydataset and read it's documentation. Create visualizations to answer the following questions:
#
#     Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
#
#     Does whether or not a province is Catholic influence fertility?
#
#     What measure correlates most strongly with fertility?

# %%
df.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
df = pydataset.data('swiss')
df['is_catholic'] = df['Catholic'] > 50.0
catholic = df[df.is_catholic == True]
non_catholic =df[df.is_catholic != True]
non_catholic
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Aigle              64.1         62.0           21         12      8.52
# Aubonne            66.9         67.5           14          7      2.27
# Avenches           68.9         60.7           19         12      4.43
# Cossonay           61.7         69.3           22          5      2.82
# Echallens          68.3         72.6           18          2     24.20
# Grandson           71.7         34.0           17          8      3.30
# Lausanne           55.7         19.4           26         28     12.11
# La Vallee          54.3         15.2           31         20      2.15
# Lavaux             65.1         73.0           19          9      2.84
# Morges             65.5         59.8           22         10      5.23
# Moudon             65.0         55.1           14          3      4.52
# Nyone              56.6         50.9           22         12     15.14
# Orbe               57.4         54.1           20          6      4.20
# Oron               72.5         71.2           12          1      2.40
# Payerne            74.2         58.1           14          8      5.23
# Paysd'enhaut       72.0         63.5            6          3      2.56
# Rolle              60.5         60.8           16         10      7.72
# Vevey              58.3         26.8           25         19     18.46
# Yverdon            65.4         49.5           15          8      6.10
# Boudry             70.4         38.4           26         12      5.62
# La Chauxdfnd       65.7          7.7           29         11     13.79
# Le Locle           72.7         16.7           22         13     11.22
# Neuchatel          64.4         17.6           35         32     16.92
# Val de Ruz         77.6         37.6           15          7      4.97
# ValdeTravers       67.6         18.7           25          7      8.65
# V. De Geneve       35.0          1.2           37         53     42.34
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Moutier                   20.3        False
# Neuveville                20.6        False
# Aigle                     16.5        False
# Aubonne                   19.1        False
# Avenches                  22.7        False
# Cossonay                  18.7        False
# Echallens                 21.2        False
# Grandson                  20.0        False
# Lausanne                  20.2        False
# La Vallee                 10.8        False
# Lavaux                    20.0        False
# Morges                    18.0        False
# Moudon                    22.4        False
# Nyone                     16.7        False
# Orbe                      15.3        False
# Oron                      21.0        False
# Payerne                   23.8        False
# Paysd'enhaut              18.0        False
# Rolle                     16.3        False
# Vevey                     20.9        False
# Yverdon                   22.5        False
# Boudry                    20.3        False
# La Chauxdfnd              20.5        False
# Le Locle                  18.9        False
# Neuchatel                 23.0        False
# Val de Ruz                20.0        False
# ValdeTravers              19.5        False
# V. De Geneve              18.0        False

# %%
plt.subplot(221)
sns.histplot(data=non_catholic, x='Fertility')
plt.title('non_catholic')

plt.subplot(222)
sns.histplot(data=catholic, x='Fertility')
plt.title('catholic')
# Out:
# Text(0.5, 1.0, 'catholic')

# %% [markdown]
# Load the chipotle dataset from SQL, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
def get_db_url(username,password,hostname):
    database = input('what database?: ')
    return f'mysql+pymysql://{username}:{password}@{hostname}/{database}'
import env
url = get_db_url(env.user, env.password, env.host)

# %%
df = pd.read_sql('select * from orders', url)
df.item_price = df.item_price.strip('$').asfloat()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/f_/27df3wfj0r13yh21s8dc4jyr0000gn/T/ipykernel_6254/2466546423.py in ?()
#       1 df = pd.read_sql('select * from orders', url)
# ----> 2 df.item_price = df.item_price.strip('$').asfloat()
#       3 df.head()
#
# ~/codeup-data-science/ds-libraries-exercises/venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
# grabbed the top 4
top4 = df.groupby('item_name').size().sort_values(ascending= False).head(4)

# %%
df.

# %% [markdown]
# Load the sleepstudy dataset from pydataset and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.
